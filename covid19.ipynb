# %%
# data source:
# https://covid19.who.int/table

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#covid_all = pd.read_csv('WHO COVID-19 global table data August 6th 2021 at 11.17.16 AM.csv', index_col=False)
covid_all = pd.read_csv('WHO COVID-19 global table data September 14th 2021 at 8.53.59 AM.csv', index_col=False)

# %%
covid_all['Percentage of deaths to cumulative total'] = (covid_all['Deaths - cumulative total'] / covid_all['Cases - cumulative total']) * 100

# %%
covid_all.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 224511226
# 1  United States of America         Americas                  40675578
# 2                     India  South-East Asia                  33264175
# 3                    Brazil         Americas                  20989164
# 4        The United Kingdom           Europe                   7226280
#
#    Cases - cumulative total per 100000 population  \
# 0                                     2880.365174
# 1                                    12288.600000
# 2                                     2410.440000
# 3                                     9874.490000
# 4                                    10644.730000
#
#    Cases - newly reported in last 7 days  \
# 0                                3764498
# 1                                 939266
# 2                                 236554
# 3                                 111300
# ...

# %%
covid_all[covid_all['Name'] == 'Saudi Arabia']
# Out:
#             Name             WHO Region  Cases - cumulative total  \
# 51  Saudi Arabia  Eastern Mediterranean                    545992
#
#     Cases - cumulative total per 100000 population  \
# 51                                         1568.32
#
#     Cases - newly reported in last 7 days  \
# 51                                    749
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 51                                               2.15
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 51                                       80                       8623
#
#     Deaths - cumulative total per 100000 population  \
# 51                                            24.77
#
#     Deaths - newly reported in last 7 days  \
# 51                                      44
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 51                                               0.13
#
# ...

# %%
#covid_all.dateRep = pd.to_datetime(covid_all.dateRep)
covid_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 238 entries, Global to Tuvalu
# Data columns (total 13 columns):
# Name                                                            237 non-null object
# WHO Region                                                      238 non-null int64
# Cases - cumulative total                                        237 non-null float64
# Cases - cumulative total per 100000 population                  238 non-null int64
# Cases - newly reported in last 7 days                           237 non-null float64
# Cases - newly reported in last 7 days per 100000 population     238 non-null int64
# Cases - newly reported in last 24 hours                         238 non-null int64
# Deaths - cumulative total                                       237 non-null float64
# Deaths - cumulative total per 100000 population                 238 non-null int64
# Deaths - newly reported in last 7 days                          237 non-null float64
# ...

# %%
#covid_ksa = covid_all[covid_all.countriesAndTerritories == 'Saudi Arabia']
covid_ksa = covid_all.loc[covid_all['Name'] == 'Saudi Arabia']

# %%
covid_ksa
# Out:
#             Name             WHO Region  Cases - cumulative total  \
# 51  Saudi Arabia  Eastern Mediterranean                    545992
#
#     Cases - cumulative total per 100000 population  \
# 51                                         1568.32
#
#     Cases - newly reported in last 7 days  \
# 51                                    749
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 51                                               2.15
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 51                                       80                       8623
#
#     Deaths - cumulative total per 100000 population  \
# 51                                            24.77
#
#     Deaths - newly reported in last 7 days  \
# 51                                      44
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 51                                               0.13
#
# ...

# %%
nan_values = covid_all.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# Name                                                            False
# WHO Region                                                       True
# Cases - cumulative total                                        False
# Cases - cumulative total per 100000 population                   True
# Cases - newly reported in last 7 days                           False
# Cases - newly reported in last 7 days per 100000 population      True
# Cases - newly reported in last 24 hours                         False
# Deaths - cumulative total                                       False
# Deaths - cumulative total per 100000 population                  True
# Deaths - newly reported in last 7 days                          False
# Deaths - newly reported in last 7 days per 100000 population     True
# Deaths - newly reported in last 24 hours                        False
# Percentage of deaths to cumulative total                         True
# dtype: bool

# %%
# Print columns with missing values in a list 
nan_columns_list = covid_all.columns[covid_all.isnull().any()]
nan_columns_list
# Out:
# Index(['WHO Region', 'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Percentage of deaths to cumulative total'],
#       dtype='object')

# %%
covid_distribution_counts = covid_all['Cases - newly reported in last 24 hours'].value_counts()

# %%
# Pie plot 

plt.figure(figsize=(12, 6))
plt.title('Cases - newly reported in last 24 hours')
plt.pie(covid_distribution_counts, labels=covid_distribution_counts.index, autopct='%1.1f%%', startangle=150, shadow=True);
