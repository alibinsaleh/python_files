# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
students = pd.read_csv('source/haseb2-1442-2nd term.csv')

# %%
students.head()
# Out:
#    id  classroom  academic_num                         student_name  \
# 0   1        204         40004         محمود بن فيصل بن حسين الشهاب
# 1   2        204         40018  محمد بن بديع بن عبدالله الحاجي محمد
# 2   3        204         40029       مهدي بن بدر بن عبدالوهاب بوحسن
# 3   4        204         40062      عبدالله بن زهير بن ياسين الصالح
# 4   5        204         40069     عبدالعزيز بن سامي بن طاهر القطان
#
#    short_practical  short_theoretical  projects  participation  homework  \
# 0              9.0               10.0       3.0            5.0       5.0
# 1             10.0               15.0       9.0            5.0      10.0
# 2             10.0               15.0      15.0           19.0      14.0
# 3             10.0               14.5      15.0           13.0      14.0
# 4              9.5               15.0       9.0           14.0      14.0
#
#    portfolio  final_theoretical  final_project  attendance  total
# ...

# %%
students[students['total'] > 70]
# Out:
#     id  classroom  academic_num                           student_name  \
# 2    3        204         40029         مهدي بن بدر بن عبدالوهاب بوحسن
# 3    4        204         40062        عبدالله بن زهير بن ياسين الصالح
# 6    7        204         40074            مهدي بن يوسف بن ناصر الجاسم
# 8    9        204         40081         حسن بن احمد بن عبدالله الفرحان
# 9   10        204         40083       الياس بن حسين بن عبدالله السبيعي
# 12  13        204         40122     الحسين بن احمد بن عبدالعظيم البقشي
# 13  14        204         40155               حسن بن علي بن حسن الغريب
# 18  19        204         40219              حسين بن علي بن احمد السني
# 23  24        204         40256                محمد راضي بن علي السويق
# 27  28        205         40064         محمد بن سلمان بن محمد البراهيم
# 29  30        205         40067            محمد بن مهدي بن جمعه البناي
# 30  31        205         40108     نذير بن عدنان بن عبد المطلب آل حسن
# ...

# %%
students.plot()

# %%
names = students['student_name']
totals = students['total']

# %%
students_dictionary = {'name': names,
                      'total': totals}

# %%
print(students_dictionary)
# Out:
# {'name': 0            محمود بن فيصل بن حسين الشهاب
# 1     محمد بن بديع بن عبدالله الحاجي محمد
# 2          مهدي بن بدر بن عبدالوهاب بوحسن
# 3         عبدالله بن زهير بن ياسين الصالح
# 4        عبدالعزيز بن سامي بن طاهر القطان
# 5             سجاد بن صالح بن موسى الغانم
# 6             مهدي بن يوسف بن ناصر الجاسم
# 7         ضياء بن وحيد بن عبدالله الحماده
# 8          حسن بن احمد بن عبدالله الفرحان
# 9        الياس بن حسين بن عبدالله السبيعي
# 10         وضاح بن محمد بن عبدالله المسلم
# 11         مصطفى بن توفيق بن محمد الهودار
# 12     الحسين بن احمد بن عبدالعظيم البقشي
# 13               حسن بن علي بن حسن الغريب
# 14              علي بن انور بن علي البقشي
# 15             علي بن جابر بن طاهر القظيب
# 16        علي بن طالب بن عبدالحميد البقشي
# 17           محمد بن فاضل بن ابراهيم لبوي
# 18              حسين بن علي بن احمد السني
# 19               فرج مسفر بن فرج العرجاني
# 20               منير حمد بن فرج العرجاني
# 21               ناصر حمد بن فرج العرجاني
# ...

# %% [markdown]
# ### Regex

# %%
import re
phoneNumReg = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
mo = phoneNumReg.search('My number is 415-555-4242.')
print('Phone number found: ' + mo.group())
# Out:
# Phone number found: 415-555-4242

# %% [markdown]
# ### clipboard library

# %%
import pyperclip
text = pyperclip.paste()

# %%
text.split('\n')
# Out:
# ['“The lines list now contains modified lines that start with stars. But pyperclip.copy() is expecting a single string value, not a list of string values. To make this single string value, pass lines into the join() method to get a single string joined from the list’s strings. Make your program look like the following:”',
#  '',
#  'Excerpt From: Al Sweigart. “Automate the Boring Stuff with Python.” iBooks. ']

# %%
lines = text.split('\n')
for i in range(len(lines)):
    lines[i] = '* ' + lines[i]

# %%
lines
# Out:
# ['* “The lines list now contains modified lines that start with stars. But pyperclip.copy() is expecting a single string value, not a list of string values. To make this single string value, pass lines into the join() method to get a single string joined from the list’s strings. Make your program look like the following:”',
#  '* ',
#  '* Excerpt From: Al Sweigart. “Automate the Boring Stuff with Python.” iBooks. ']
