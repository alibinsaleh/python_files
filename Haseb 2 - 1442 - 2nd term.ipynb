# %% [markdown]
# ### حاسب ٢ لعام ١٤٤٢ الفصل الدراسي الثاني

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("source/haseb2-1442-2nd term.csv")

# %%
df.head(73)
# Out:
#     id  classroom  academic_num                         student_name  \
# 0    1        204         40004         محمود بن فيصل بن حسين الشهاب
# 1    2        204         40018  محمد بن بديع بن عبدالله الحاجي محمد
# 2    3        204         40029       مهدي بن بدر بن عبدالوهاب بوحسن
# 3    4        204         40062      عبدالله بن زهير بن ياسين الصالح
# 4    5        204         40069     عبدالعزيز بن سامي بن طاهر القطان
# 5    6        204         40073          سجاد بن صالح بن موسى الغانم
# 6    7        204         40074          مهدي بن يوسف بن ناصر الجاسم
# 7    8        204         40079      ضياء بن وحيد بن عبدالله الحماده
# 8    9        204         40081       حسن بن احمد بن عبدالله الفرحان
# 9   10        204         40083     الياس بن حسين بن عبدالله السبيعي
# 10  11        204         40093       وضاح بن محمد بن عبدالله المسلم
# 11  12        204         40101       مصطفى بن توفيق بن محمد الهودار
# 12  13        204         40122   الحسين بن احمد بن عبدالعظيم البقشي
# ...

# %%
df.describe()
# Out:
#               id   classroom  academic_num  short_practical  \
# count  73.000000   73.000000     73.000000        73.000000
# mean   37.000000  205.013699  40145.219178         9.219178
# std    21.217131    0.824843     71.760064         1.076860
# min     1.000000  204.000000  40004.000000         6.000000
# 25%    19.000000  204.000000  40087.000000         9.000000
# 50%    37.000000  205.000000  40148.000000         9.500000
# 75%    55.000000  206.000000  40210.000000        10.000000
# max    73.000000  206.000000  40256.000000        10.000000
#
#        short_theoretical   projects  participation   homework  portfolio  \
# count          73.000000  73.000000      73.000000  73.000000       73.0
# mean           14.335616   9.821918      15.671233  12.808219        0.0
# std             1.650031   5.031408       5.979258   3.094159        0.0
# min             5.000000   3.000000       5.000000   6.000000        0.0
# ...

# %%
temp = df.sort_values('total')
temp.head(38)
# Out:
#     id  classroom  academic_num                         student_name  \
# 72  73        206         40248      عبدالله احمد بن عبدالله الحماده
# 44  45        205         40212           متعب بن يحيى بن عايل فرزعي
# 0    1        204         40004         محمود بن فيصل بن حسين الشهاب
# 7    8        204         40079      ضياء بن وحيد بن عبدالله الحماده
# 61  62        206         40173      محمد بن عبدالاله بن محمد الصحاف
# 50  51        206         40087    قاسم بن علي بن عبدالوهاب البحراني
# 10  11        204         40093       وضاح بن محمد بن عبدالله المسلم
# 49  50        206         40040  حسين بن عبدالعزيز بن ابراهيم الدوخي
# 24  25        205         40006      حسين بن علي بن حبيب العبداللطيف
# 19  20        204         40243             فرج مسفر بن فرج العرجاني
# 56  57        206         40129       محمد بن يوسف بن علي الشيخ صالح
# 62  63        206         40198          محمود بن محمد بن علي ابوخضر
# 25  26        205         40016     احمد بن ابراهيم بن راضي ابوناجمه
# ...

# %%
df[df["academic_num"] == 40108]
# Out:
#     classroom  academic_num                        student_name  total
# 30        205         40108  نذير بن عدنان بن عبد المطلب آل حسن   94.5

# %%
df = df[['classroom', 'academic_num', 'student_name', 'projects', 'total']]

classroom = df[df["classroom"] == 206]


result_df = classroom[classroom["total"] > 89]
result_df.rename(columns = {'classroom': 'الشعبة', 'academic_num': 'الرقم الأكاديمي', 'student_name': 'اسم الطالب', 'projects': 'المشروعات', 'total': 'المجموع'}, inplace = True)

result_df.head(25)
# Out:
#     الشعبة  الرقم الأكاديمي                        اسم الطالب  المشروعات  \
# 48     206            40012    محمد بن هاني بن عبدالله المطوع       15.0
# 51     206            40092      مهدي بن مسلم بن ياسين السالم       15.0
# 53     206            40109     عبدالله بن هشام بن علي الهاشم       15.0
# 55     206            40123  عبدالله بن بندر بن ياسين العمران       15.0
# 58     206            40142       علي بن جميل بن حسين القريشي       15.0
# 59     206            40147     علي بن هاني بن عبدالله المطوع       15.0
# 66     206            40213                  يزن علي حسن فندي       15.0
# 71     206            40238       صالح بن سالم بن عيد روس دوح       15.0
#
#     المجموع
# 48     92.5
# 51     94.0
# 53     95.0
# 55     95.0
# 58     95.0
# 59     94.0
# 66     95.0
# 71     94.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 14 columns):
# id                   73 non-null int64
# classroom            73 non-null int64
# academic_num         73 non-null int64
# student_name         73 non-null object
# short_practical      73 non-null float64
# short_theoretical    73 non-null float64
# projects             73 non-null float64
# participation        73 non-null float64
# homework             73 non-null float64
# portfolio            73 non-null float64
# final_theoretical    73 non-null float64
# final_project        73 non-null float64
# attendance           73 non-null float64
# total                73 non-null float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 8.1+ KB

# %%
#df[df["total"] > 30]
m = df["projects"].max()
x = df[df["projects"] == m]
c204 = x[x["classroom"] == 206]
c204
# Out:
#     classroom  academic_num                      student_name  projects  total
# 48        206         40012    محمد بن هاني بن عبدالله المطوع      15.0   92.5
# 51        206         40092      مهدي بن مسلم بن ياسين السالم      15.0   94.0
# 53        206         40109     عبدالله بن هشام بن علي الهاشم      15.0   95.0
# 55        206         40123  عبدالله بن بندر بن ياسين العمران      15.0   95.0
# 58        206         40142       علي بن جميل بن حسين القريشي      15.0   95.0
# 59        206         40147     علي بن هاني بن عبدالله المطوع      15.0   94.0
# 66        206         40213                  يزن علي حسن فندي      15.0   95.0
# 71        206         40238       صالح بن سالم بن عيد روس دوح      15.0   94.0

# %%
graph = df[df["classroom"] == 205]
graph.plot(x="academic_num", y="total", kind="bar")
